# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
path = r'D:\0_Respaldo\0_Proyectos_2024\ML_proyects\Kagel_Bynary_prediction_Poisonus Mushrooms\mushroom\data\raw\train.csv'

# %%
data = pd.read_csv(path)

# %%
df = data.copy()

# %%
df.sample(5)
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 1108904  1108904     p          3.99         b           t         l
# 2029207  2029207     p          4.75         s         NaN         n
# 2485438  2485438     e          5.49         f           y         g
# 2018588  2018588     p          1.49         x         NaN         n
# 2040125  2040125     e         18.17         s           s         k
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 1108904                    f               s            c          n  ...
# 2029207                    t               d            c          b  ...
# 2485438                    f               s          NaN          w  ...
# 2018588                    f             NaN          NaN          n  ...
# 2040125                    f               a            d          k  ...
#
#          stem-root  stem-surface stem-color veil-type veil-color has-ring  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3116945 entries, 0 to 3116944
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   class                 object
#  2   cap-diameter          float64
#  3   cap-shape             object
#  4   cap-surface           object
#  5   cap-color             object
#  6   does-bruise-or-bleed  object
#  7   gill-attachment       object
#  8   gill-spacing          object
#  9   gill-color            object
#  10  stem-height           float64
#  11  stem-width            float64
#  12  stem-root             object
#  13  stem-surface          object
#  14  stem-color            object
#  15  veil-type             object
#  16  veil-color            object
#  17  has-ring              object
#  18  ring-type             object
#  19  spore-print-color     object
#  20  habitat               object
#  21  season                object
# ...

# %%
columnas_discretas = df.select_dtypes(include=['int','float']).columns.tolist()

# %%
for col in columnas_discretas:
    plt.figure(figsize=(6, 3))
    plt.hist(df[col], bins=30, edgecolor='black')  # Puedes ajustar los bins según sea necesario
    plt.title(f'Histograma de {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.show()

# %% [markdown]
# Columnas categoricas

# %%
columnas_categoricas = df.select_dtypes(include=['object','category']).columns.tolist()

# %%
for col in columnas_categoricas:
    plt.figure(figsize=(10, 4))
    sns.countplot(data=df, x=col, palette='viridis')
    plt.title(f'Conteo de categorías en {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.xticks(rotation=45)  # Rotar etiquetas si es necesario
    plt.show()
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16820\1717486267.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16820\1717486267.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16820\1717486267.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# ...

# %%
df.shape
# Out:
# (3116945, 22)

# %% [markdown]
# I will filter the data :
# spore print color > 2500
# has ring > 0.5
# veil color > 10000
# geil color > 10000

# %%
df1= df.copy()

# %%
col_x = ['a','x','s','d','e','f','p']

# %%
df1 = df1[df1['has-ring'].isin(col_x)]

# %%
df1.shape
# Out:
# (2368857, 22)

# %%
col_y = ['s','h','y','l','t','e','g','d','i','w','k']

# %%
df1 = df1[df1['cap-surface'].isin(col_y)]

# %%
df1.shape
# Out:
# (1810654, 22)

# %%
col_n = ['f','z','e','p','l','g','r','m','y']

# %%
df1 = df1[df1['ring-type'].isin(col_n)]

# %%
df1.shape
# Out:
# (1810523, 22)

# %%
col_e = ['a','x','s','d','e','f','p']

# %%
df1 = df1[df1['gill-attachment'].isin(col_e)]
df1.shape
# Out:
# (1528562, 22)

# %%
for col in columnas_categoricas:
    plt.figure(figsize=(10, 4))
    sns.countplot(data=df1, x=col, palette='viridis')
    plt.title(f'Conteo de categorías en {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.xticks(rotation=45)  # Rotar etiquetas si es necesario
    plt.show()
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16820\786545127.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df1, x=col, palette='viridis')
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16820\786545127.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df1, x=col, palette='viridis')
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16820\786545127.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df1, x=col, palette='viridis')
# ...

# %% [markdown]
# DROOP COLUMNS [RING-TYPE, HAS-RING, VEIL-TYPE]

# %%
df2 = df1.copy()

# %%
del df2['ring-type']
del df2['has-ring']
del df2['veil-type']

# %%
df2.shape
# Out:
# (1528562, 19)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1528562 entries, 0 to 3116944
# Data columns (total 19 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1528562 non-null  int64
#  1   class                 1528562 non-null  object
#  2   cap-diameter          1528561 non-null  float64
#  3   cap-shape             1528552 non-null  object
#  4   cap-surface           1528562 non-null  object
#  5   cap-color             1528557 non-null  object
#  6   does-bruise-or-bleed  1528557 non-null  object
#  7   gill-attachment       1528562 non-null  object
#  8   gill-spacing          919294 non-null   object
#  9   gill-color            1528543 non-null  object
#  10  stem-height           1528562 non-null  float64
#  11  stem-width            1528562 non-null  float64
#  12  stem-root             130380 non-null   object
#  13  stem-surface          566860 non-null   object
# ...

# %%
df2['gill-spacing'] = df2['gill-spacing'].fillna('0')
df2['stem-root'] = df2['stem-root'].fillna('0')
df2['stem-surface'] = df2['stem-surface'].fillna('0')
df2['stem-color'] = df2['stem-color'].fillna('0')
df2['veil-color'] = df2['veil-color'].fillna('0')
df2['spore-print-color'] = df2['spore-print-color'].fillna('0')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1528562 entries, 0 to 3116944
# Data columns (total 19 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1528562 non-null  int64
#  1   class                 1528562 non-null  object
#  2   cap-diameter          1528561 non-null  float64
#  3   cap-shape             1528552 non-null  object
#  4   cap-surface           1528562 non-null  object
#  5   cap-color             1528557 non-null  object
#  6   does-bruise-or-bleed  1528557 non-null  object
#  7   gill-attachment       1528562 non-null  object
#  8   gill-spacing          1528562 non-null  object
#  9   gill-color            1528543 non-null  object
#  10  stem-height           1528562 non-null  float64
#  11  stem-width            1528562 non-null  float64
#  12  stem-root             1528562 non-null  object
#  13  stem-surface          1528562 non-null  object
# ...

# %%
df2.drop_duplicates()
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# 8              8     p          7.36         f           h         e
# ...          ...   ...           ...       ...         ...       ...
# 3116927  3116927     e          3.75         x           t         n
# 3116928  3116928     p          7.36         x           e         n
# 3116933  3116933     e          8.44         f           s         w
# 3116935  3116935     p         14.58         x           d         n
# 3116944  3116944     p          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# ...

# %%
df2.head(5)
# Out:
#    id class  cap-diameter cap-shape cap-surface cap-color  \
# 0   0     e          8.80         f           s         u
# 2   2     e          6.94         f           s         b
# 3   3     e          3.88         f           y         g
# 4   4     e          5.85         x           l         w
# 8   8     p          7.36         f           h         e
#
#   does-bruise-or-bleed gill-attachment gill-spacing gill-color  stem-height  \
# 0                    f               a            c          w         4.51
# 2                    f               x            c          w         6.85
# 3                    f               s            0          g         4.16
# 4                    f               d            0          w         3.37
# 8                    f               x            d          w         5.77
#
#    stem-width stem-root stem-surface stem-color veil-color spore-print-color  \
# 0       15.39         0            0          w          0                 0
# ...

# %%
path = r'D:\0_Respaldo\0_Proyectos_2024\ML_proyects\Kagel_Bynary_prediction_Poisonus Mushrooms\mushroom\data\clean\clean.parquet'

# %%
df2.to_parquet(path, index=False)
